# %% [markdown]
# # RheolNet — Data Pipeline (Aditya)
#
# GitHub repo: https://github.com/ath4trva/RheolNet
# Branch: https://github.com/ath4trva/RheolNet/tree/Aditya_data_pipeline

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/adityapatil71/aneumo-case-10651/10651.stl

# %%
# !git clone -b Aditya_data_pipeline https://github.com/ath4trva/RheolNet.git
# Out:
# Cloning into 'RheolNet'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 62 (delta 20), reused 35 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (62/62), 374.73 KiB | 3.54 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
# !ls RheolNet/geometry
# Out:
# __init__.py  loader.py	sampler.py  tests

# %%
# !pip install pyvista trimesh nibabel SimpleITK h5py vtk
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 22.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 745.5/745.5 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.6/234.6 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.0/273.0 kB 7.0 MB/s eta 0:00:00
# ...

# %%
import sys
sys.path.append('RheolNet/geometry')

from loader import load_and_sample_geometry, save_to_hdf5, load_aneumo_cfd

# %%
print(load_and_sample_geometry)
print(save_to_hdf5)
print(load_aneumo_cfd)
# Out:
# <function load_and_sample_geometry at 0x7d79e0564ea0>
# <function save_to_hdf5 at 0x7d79cc26e700>
# <function load_aneumo_cfd at 0x7d79c6120220>

# %%
import os
for root, dirs, files in os.walk('/kaggle/input'):
    for f in files:
        print(os.path.join(root, f))
# Out:
# /kaggle/input/datasets/adityapatil71/aneumo-case-10651/10651.stl

# %%
pts = load_and_sample_geometry('/kaggle/input/datasets/adityapatil71/aneumo-case-10651/10651.stl')
save_to_hdf5(pts, '/kaggle/working/case_001_collocation.h5')
print({k: v.shape for k, v in pts.items()})
# Out:
# Mesh loaded: 15253 points, 29924 cells
# Saved to /kaggle/working/case_001_collocation.h5
# {'interior': (50000, 3), 'wall': (10000, 3), 'inlet': (234, 3)}
